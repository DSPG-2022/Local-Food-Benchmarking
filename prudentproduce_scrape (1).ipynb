# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

html_text = requests.get("https://www.prudentproduce.net/shop/fruit").text
soup = BeautifulSoup(html_text, "lxml")
items = soup.find_all('div', class_ = 'span4 v2shopitem')

dfObj = pd.DataFrame(columns = ["Item Name", "Unit of Measurement", 'Price'])

for item in items:
  item_name = item.find('div', class_ = "smlholder").text.strip()
  item_unit = item.find("div", class_ = "pull-left shopunitsv2").text.strip()
  item_price = item.find("div", class_ = "pull-right shoppricesv3").text.replace(" ", "")
  item_price_list = item_price.split()
  item_price = item_price_list[1] + item_price_list[0]

  dfObj = dfObj.append({"Item Name": item_name, "Unit of Measurement": item_unit, "Price": item_price},
                       ignore_index = True)

# %%
dfObj
# Out:
#                        Item Name Unit of Measurement Price
# 0            Apples, Bag of Gala             3lb bag  6.59
# 1      Apples, Bag of HoneyCrisp             3lb bag  8.69
# 2               Apples, Braeburn                each  1.09
# 3           Apples, Granny Smith                each  1.19
# 4         Apples, juicing/baking             5lb bag  3.99
# 5                        Avocado                each  2.29
# 6                        Bananas                each  0.69
# 7             Bananas, very ripe                each  0.25
# 8            Berry, Blackberries                 6oz  4.99
# 9             Berry, Blueberries                6 oz  4.99
# 10            Berry, Raspberries                6 oz  4.99
# 11           Berry, Strawberries                  lb  6.99
# 12                 Date, Medjool            5 oz bag  2.79
# 13       Grapefruit, Desert Ruby                each  1.99
# 14                   Grapes, Red                1 lb  4.59
# ...

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

html_text = requests.get("https://www.prudentproduce.net/shop/vegetables").text
soup = BeautifulSoup(html_text, "lxml")
items = soup.find_all('div', class_ = 'span4 v2shopitem')


for item in items:
  item_name = item.find('div', class_ = "smlholder").text.strip()
  item_unit = item.find("div", class_ = "pull-left shopunitsv2").text.strip()
  item_price = item.find("div", class_ = "pull-right shoppricesv3").text.replace(" ", "")
  item_price_list = item_price.split()
  item_price = item_price_list[1] + item_price_list[0]

  dfObj = dfObj.append({"Item Name": item_name, "Unit of Measurement": item_unit, "Price": item_price},
                       ignore_index = True)

# %%
html_text = requests.get("https://www.prudentproduce.net/shop/eggs-1").text
soup = BeautifulSoup(html_text, "lxml")
items = soup.find_all('div', class_ = 'span4 v2shopitem')


for item in items:
  item_name = item.find('div', class_ = "smlholder").text.strip()
  item_unit = item.find("div", class_ = "pull-left shopunitsv2").text.strip()
  item_price = item.find("div", class_ = "pull-right shoppricesv3").text.replace(" ", "")
  item_price_list = item_price.split()
  item_price = item_price_list[1] + item_price_list[0]

  dfObj = dfObj.append({"Item Name": item_name, "Unit of Measurement": item_unit, "Price": item_price},
                       ignore_index = True)

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

html_text = requests.get("https://www.prudentproduce.net/shop/dairy").text
soup = BeautifulSoup(html_text, "lxml")
items = soup.find_all('div', class_ = 'span4 v2shopitem')


for item in items:
  item_name = item.find('div', class_ = "smlholder").text.strip()
  item_unit = item.find("div", class_ = "pull-left shopunitsv2").text.strip()
  item_price = item.find("div", class_ = "pull-right shoppricesv3").text.replace(" ", "")
  item_price_list = item_price.split()
  item_price = item_price_list[1] + item_price_list[0]

  dfObj = dfObj.append({"Item Name": item_name, "Unit of Measurement": item_unit, "Price": item_price},
                       ignore_index = True)

dfObj
# Out:
#                             Item Name Unit of Measurement Price
# 0                 Apples, Bag of Gala             3lb bag  6.59
# 1           Apples, Bag of HoneyCrisp             3lb bag  8.69
# 2                    Apples, Braeburn                each  1.09
# 3                Apples, Granny Smith                each  1.19
# 4              Apples, juicing/baking             5lb bag  3.99
# ..                                ...                 ...   ...
# 85       Milk, Whole, VVF, one gallon              Gallon  7.49
# 86                       Milk, 2%, PF            1 Gallon  6.75
# 87                Milk, Chocolate, PF            1 Gallon  8.99
# 88    Milk, Whole, Radiance, half gal          1/2 Gallon  4.75
# 89  Milk, Whole, Radiance, one gallon            1 Gallon  8.75
#
# [90 rows x 3 columns]

# %%
html_text = requests.get("https://www.prudentproduce.net/shop/nuts").text
soup = BeautifulSoup(html_text, "lxml")
items = soup.find_all('div', class_ = 'span4 v2shopitem')


for item in items:
  item_name = item.find('div', class_ = "smlholder").text.strip()
  item_unit = item.find("div", class_ = "pull-left shopunitsv2").text.strip()
  item_price = item.find("div", class_ = "pull-right shoppricesv3").text.replace(" ", "")
  item_price_list = item_price.split()
  item_price = item_price_list[1] + item_price_list[0]

  dfObj = dfObj.append({"Item Name": item_name, "Unit of Measurement": item_unit, "Price": item_price},
                       ignore_index = True)

dfObj
# Out:
#                     Item Name Unit of Measurement  Price
# 0         Apples, Bag of Gala             3lb bag   6.59
# 1   Apples, Bag of HoneyCrisp             3lb bag   8.69
# 2            Apples, Braeburn                each   1.09
# 3        Apples, Granny Smith                each   1.19
# 4      Apples, juicing/baking             5lb bag   3.99
# ..                        ...                 ...    ...
# 91    Almonds, Whole raw, 5lb             5lb bag  43.99
# 92               Pecan pieces            1-lb bag  13.00
# 93      Raw cashew pieces 1lb                 1lb  10.99
# 94      Raw cashew pieces 5lb                 5lb  47.99
# 95                    Walnuts                8 oz   8.99
#
# [96 rows x 3 columns]

# %%
file_name = 'PrudentProduce_sheet.xlsx'
  
# saving the excelsheet
dfObj.to_excel(file_name)
